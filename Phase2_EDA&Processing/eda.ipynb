# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer

# %%
def perform_eda(file_path):
    # Load dataset
    df = perform_eda("../Phase1_DataCollection/data/heart.csv")

# %%
def perform_eda(file_path):
    # Load dataset
    df = perform_eda("../Phase1_DataCollection/data/heart.csv")
    return df  # Add this line
# --- 1. Missing Value Handling ---
# Identify and impute missing values to ensure the pipeline doesn't break
def perform_eda(file_path):
    # Load dataset
    df = perform_eda("../Phase1_DataCollection/data/heart.csv")
    
    # --- 1. Missing Value Handling ---
    # Identify and impute missing values to ensure the pipeline doesn't break
    if df.isnull().sum().sum() > 0:
        print("Missing values detected. Handling via median imputation...")
        imputer = SimpleImputer(strategy='median')
        df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
    else:
        print("Dataset integrity verified: No missing values detected.")
    
    return df  # Add this line

# %%
# --- 2. Data Cleaning & Transformation ---
if __name__ == "__main__":
    df = pd.read_csv("../Phase1_DataCollection/data/heart.csv", sep=',')
    df["age"] = df["age"] / 365  
# Convert days to years
df["age"] = df["age"] / 365

# %%
# --- 3. Statistical Analysis ---
print("\n--- Descriptive Statistics ---")
print(df.describe())
# Out:
# --- Descriptive Statistics ---
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean      0.000409     0.695610     0.942439   131.611707   246.00000
# std       0.000068     0.460373     1.029641    17.516718    51.59251
# min       0.000218     0.000000     0.000000    94.000000   126.00000
# 25%       0.000360     0.000000     0.000000   120.000000   211.00000
# 50%       0.000420     1.000000     1.000000   130.000000   240.00000
# 75%       0.000458     1.000000     2.000000   140.000000   275.00000
# max       0.000578     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
# --- 4. Visualization ---
sns.set_theme(style="whitegrid")

# %%
# Target distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='target', data=df)
plt.title('Distribution of Target (Heart Disease)')
plt.show()

# %%
# Age vs Disease relationship
plt.figure(figsize=(8, 4))
sns.histplot(data=df, x='age', hue='target', kde=True, element="step")
plt.title('Age Distribution by Heart Disease Status')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
if __name__ == "__main__":
    if __name__ == "__main__":
        df = pd.read_csv("../Phase1_DataCollection/data/heart.csv", sep=';')
